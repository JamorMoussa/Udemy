# %%
from PIL import Image

# %%
im = Image.open("../image.jpeg")

# %%
im.size
# Out:
# (279, 181)

# %%
width, height = im.size

# %%
width
# Out:
# 279

# %%
height
# Out:
# 181

# %%
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4

# %%
cropped_img = im.crop((left,top,right,bottom))

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=279x181>

# %%
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=159x91>
